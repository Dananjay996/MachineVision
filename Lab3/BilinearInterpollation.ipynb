# %%
#Perform bilinear interpolation on a image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = plt.imread("../images/blackAndWhiteImage.webp")
plt.imshow(image)

# %%
def bipolar_interpollation(image):
