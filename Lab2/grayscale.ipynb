# %%
import matplotlib.pyplot as plt
image = plt.imread("../images/grayScale.jpeg")
plt.imshow(image, interpolation=None)

# %%
print(image)
# Out:
# [[[255 255 255]
#   [252 252 252]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [252 252 252]]
#
#  [[251 251 251]
#   [255 255 255]
#   [250 250 250]
#   ...
#   [255 255 255]
#   [245 245 245]
#   [255 255 255]]
#
#  [[248 248 248]
#   [255 255 255]
#   [176 176 176]
#   ...
#   [139 139 139]
#   [255 255 255]
#   [253 253 253]]
#
#  ...
#
#  [[255 255 255]
#   [250 250 250]
#   [207 207 207]
#   ...
#   [129 129 129]
#   [255 255 255]
#   [255 255 255]]
#
#  [[252 252 252]
#   [255 255 255]
#   [253 253 253]
#   ...
#   [251 251 251]
#   [255 255 255]
#   [249 249 249]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [252 252 252]
#   [251 251 251]]]

# %%
# Print the 0,0 pixel value of the image
print(image[0][0])
# Out:
# [255 255 255]

# %%
# Print the min and max pixel values of the image
print(image.max())
print(image.min())
# Out:
# 255
# 0
