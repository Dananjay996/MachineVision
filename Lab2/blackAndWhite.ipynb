# %%
import matplotlib.pyplot as plt

#Reading an Image
image = plt.imread("../images/blackAndWhiteImage.webp")
plt.imshow(image, interpolation=None)

# %%
print(image)
# Out:
# [[[ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]
#   ...
#   [ 8  8  8]
#   [ 3  3  3]
#   [17 17 17]]
#
#  [[ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]
#   ...
#   [ 8  8  8]
#   [ 3  3  3]
#   [16 16 16]]
#
#  [[ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]
#   ...
#   [ 8  8  8]
#   [ 5  5  5]
#   [14 14 14]]
#
#  ...
#
#  [[ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]
#   ...
#   [ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]]
#
#  [[ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]
#   ...
#   [ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]]
#
#  [[ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]
#   ...
#   [ 6  6  6]
#   [ 6  6  6]
#   [ 6  6  6]]]

# %%
# Print the 0,0 pixel value of the image
print(image[0][0])
# Out:
# [6 6 6]

# %%
# Print the min and max pixel values of the image
print(image.max())
print(image.min())
# Out:
# 255
# 0
